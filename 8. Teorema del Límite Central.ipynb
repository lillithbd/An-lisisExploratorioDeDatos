# %% [markdown]
# # Ley de los Grandes Números y Teorema del Límite Central

# %% [markdown]
# ## Instalar librerías necesarias

# %%
# !pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# ...

# %% [markdown]
# #

# %%
# !pip install palmerpenguins==0.1.4 numpy==1.23.4 pandas==1.5.1 seaborn==0.12.1 matplotlib==3.6.0 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.1.2 pyjanitor==0.23.1 session-info
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Not uninstalling packaging at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'packaging'. No files were found to uninstall.
# ...

# %% [markdown]
# ## Importar librerías

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %% [markdown]
# ## Establecer apariencia general de los gráficos

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# ## Cargar los datos

# %% [markdown]
# ### Utilizando el paquete palmerpinguins

# %% [markdown]
# Datos crudos

# %%
raw_penguins_df = palmerpenguins.load_penguins_raw()
raw_penguins_df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %% [markdown]
# Datos previamente procesados

# %%
preprocessed_penguins_df = palmerpenguins.load_penguins()
preprocessed_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# ### Utilizando los conjuntos de datos de seaborn

# %%
preprocessed_penguins_df = sns.load_dataset("penguins")

# %% [markdown]
# ### Utilizando la interfaz de Deepnote

# %% [markdown]
# Links de importación de datos

# %% [markdown]
# Conjunto de datos crudos
# https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins_raw.csv

# %% [markdown]
# Conjunto de datos previamente procesados
# https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv

# %%
raw_penguins_df2 = pd.read_csv('penguins_raw.csv')
raw_penguins_df2
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# ...

# %%
preprocessed_penguins_df2 = pd.read_csv('penguins.csv')
preprocessed_penguins_df2
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# ## ¿Cuántos observaciones perdemos si eliminamos los datos faltantes?

# %%
processed_penguins_df = (
    preprocessed_penguins_df
    .dropna()
)
processed_penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # Ley de los Grandes Números y Teorema del Límite Central

# %% [markdown]
# ## Ley de los Grandes Números

# %%
#Ley de los grandes números con un dado
dice = empiricaldist.Pmf.from_seq([1, 2, 3, 4, 5, 6])
dice.bar()

# %%
for sample_size in (1e2, 1e3, 1e4):
    sample_size = int(sample_size)
    values = dice.sample(sample_size)
    #print (values)
    sample_pmf = empiricaldist.Pmf.from_seq(values)
    plt.figure(figsize=(5,5)) #Se crea una figura y se le da el tamaño
    sample_pmf.bar() #Se grafica la distribución
    plt.axhline(y=1/6, color = 'red', linestyle='dashed') #Línea x
    plt.ylim([0, 0.50]) #Línea Y 
    plt.title(f"Sample size: {sample_size}")

# %% [markdown]
# ## Teorema del Límite Central

# %%
#Calcular proporción de categoría sexo en pingüinos
processed_penguins_df.sex.value_counts(normalize=True)
# Out:
# Male      0.504505
# Female    0.495495
# Name: sex, dtype: float64

# %%
#transformación de variable categórica sexo en numérica
sex_numeric = processed_penguins_df.sex.replace(['Male', 'Female'], [1, 0])

# %%
#Tomar muestras y en cada muestreo sacar 35 pingüinos de la muestra y validar proporción de machos
number_samples = 1000
sample_size=35

samples_df = pd.DataFrame()

np.random.seed(42)
for i in range(1, number_samples + 1):
    sex_numeric_sample = sex_numeric.sample(sample_size, replace=True).to_numpy()
    sample_name = f"sample_{i}"
    samples_df[sample_name] = sex_numeric_sample

#Calculo del promedio de todas las muestras que tomamos
male_population_mean = samples_df.mean().mean()
print(f"Estimated percentage of male penguins in population is: {male_population_mean * 100:.4f}%")
# Out:
# /tmp/ipykernel_201/103721395.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_201/103721395.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# ...

# %%
#Graficar función de densidad
sample_means_binomial = pd.DataFrame(samples_df.mean(), columns=['sample_mean'])
sns.kdeplot(data=sample_means_binomial)
plt.axvline(x=sex_numeric.mean(), color='red', linestyle='dashed')
#Mediareal : punto rojo

# %%
#Explorar el efecto de incrementar el tamaño de las muestras en la estimación del valor final
sample_size_experiment = pd.DataFrame(
    [[i, samples_df.iloc[:, 0:i].mean().mean().mean()] for i in range(1, number_samples + 1)],
    columns=['sample_size', 'estimated_mean']
)

# %%
sns.scatterplot(
    data=sample_size_experiment,
    x='sample_size',
    y='estimated_mean'
)

plt.axhline(
    y=sex_numeric.mean(),
    color='red',
    linestyle='dashed'
)

plt.ylim([sex_numeric.mean() - 0.20, sex_numeric.mean() + 0.20])
#Al incrementar las muestras los puntos se acercan a la línea roja (que es la media)
# Out:
# (0.30450450450450445, 0.7045045045045044)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3747407c-0049-4827-a9f0-4cbeeed7d746' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
